# %%
import cv2
import numpy as np
import tensorflow as tf

model = tf.keras.models.load_model("basic_2D_CNN.keras")

class_names = {
    0: "Cover Drive",
    1: "Defense",
    2: "Flick",
    3: "Hook Shot",
    4: "Late Cut",
    5: "Lofted Shot",
    6: "Pull Shot",
    7: "Square Cut",
    8: "Straight Drive",
    9: "Sweep"
}

def preprocess_frame(frame):
    resized = cv2.resize(frame, (224, 224))
    normalized = resized / 255.0
    return np.expand_dims(normalized, axis=0)

cap = cv2.VideoCapture("/media/smayan/500GB SSD/Cricket/31 march/31marchbat.mov")

display_width = 640
display_height = 480


while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Preprocess the frame
    processed_frame = preprocess_frame(frame)
    
    # Make prediction
    predictions = model.predict(processed_frame)
    predicted_class = np.argmax(predictions[0])
    confidence = np.max(predictions[0])
    
    # Display prediction
    label = f"{class_names[predicted_class]}: {confidence:.2f}"
    cv2.putText(frame, label, (10, 30), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Show the frame
    cv2.imshow('Cricket Shot Classification', frame)
    
    # Exit on 'q' press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import tensorflow as tf

# Load your saved model
model = tf.keras.models.load_model("basic_2D_CNN.keras")

# Define class labels (replace with your actual class names)
class_names = {
    0: "Cover Drive",
    1: "Defense",
    2: "Flick",
    3: "Hook Shot",
    4: "Late Cut",
    5: "Lofted Shot",
    6: "Pull Shot",
    7: "Square Cut",
    8: "Straight Drive",
    9: "Sweep"
}

def preprocess_frame(frame):
    # Resize and normalize the frame
    resized = cv2.resize(frame, (224, 224))
    normalized = resized / 255.0
    return np.expand_dims(normalized, axis=0)

# Initialize webcam
cap = cv2.VideoCapture("/home/smayan/Downloads/All Cricket Shots Ever In Cricket History Part Two __ All Cricket Shots In Cricket __.mp4")

# Set a smaller display size for the window
display_width = 640
display_height = 900

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Preprocess the frame for prediction
    processed_frame = preprocess_frame(frame)
    
    # Make prediction
    predictions = model.predict(processed_frame)
    predicted_class = np.argmax(predictions[0])
    confidence = np.max(predictions[0])
    
    # Display prediction
    label = f"{class_names[predicted_class]}: {confidence:.2f}"
    cv2.putText(frame, label, (10, 30), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Resize the frame for display
    small_frame = cv2.resize(frame, (display_width, display_height))
    
    # Show the smaller frame
    cv2.imshow('Cricket Shot Classification', small_frame)
    
    # Exit on 'q' press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-04-10 18:11:29.367468: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-10 18:11:29.485117: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744288889.531061    7578 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744288889.544125    7578 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
